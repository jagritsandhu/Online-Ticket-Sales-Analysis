# %% [markdown]
# # Analyzing Online Ticket Sales with Amazon Redshift
#
# In this project, I will be accessing data stored in Amazon Redshift, a data warehouse product that is part of Amazon Web Services. More specifically, I'll be analyzing sales activity from a fictional ticketing website where users both buy and sell tickets online for sporting events, shows, and concerts ([source](https://docs.aws.amazon.com/redshift/latest/dg/c_sampledb.html)).

# %% [markdown]
# ## Aim of The Project
# Which users should we target for our advertising purposes?
# - There are several users, who have advertised or have put tickets up for sale but haven't been able to sell them effectively.
# - By recognizing these users, we can specifically target them through advertizing.
#
# ## Tech Stack
# - I'll be using SQL to query the Redshift database as well as to manipulate the data.
# - I'll also use Python to visualize this data na dform interesting conclusions.

# %% [markdown]
# ## Data Exploration Using SQL
# Let's start by exploring the events data.

# %%
-- List all the events
SELECT * FROM event
# Out:
#       eventid  venueid  catid  dateid              eventname  \
# 0         423      303      8    1827  La Damnation de Faust
# 1        2099      211      7    1827            The Bacchae
# 2        6640       38      9    1827         Herbie Hancock
# 3        8621        9      9    1827               Hot Chip
# 4        3979      127      9    1828          Alkaline Trio
# ...       ...      ...    ...     ...                    ...
# 8793     6034       45      9    2191                    War
# 8794     6783       60      9    2191             The Police
# 8795     6857       18      9    2191           Judas Priest
# 8796     7192       54      9    2191     Lindsey Buckingham
# 8797     8168       70      9    2191      Little River Band
#
#                      starttime
# 0    2008-01-01 19:30:00+00:00
# 1    2008-01-01 19:30:00+00:00
# 2    2008-01-01 19:30:00+00:00
# 3    2008-01-01 19:00:00+00:00
# 4    2008-01-02 14:30:00+00:00
# ...                        ...
# 8793 2008-12-31 14:00:00+00:00
# 8794 2008-12-31 15:00:00+00:00
# 8795 2008-12-31 14:00:00+00:00
# 8796 2008-12-31 19:30:00+00:00
# 8797 2008-12-31 15:00:00+00:00
#
# [8798 rows x 6 columns]

# %% [markdown]
# - There are around 9000 different events for year 2008 in this database.
# - This is linking up to several other tables in the warehouse, such as venue, category and date.
# - Using SQL's 'INNER JOIN' capability, let's join things up to see a much detailed table.

# %%
-- joining venue and category tables to the events table
SELECT *
FROM event
INNER JOIN venue USING(venueid)
INNER JOIN category USING(catid)
INNER JOIN date USING(dateid)
LIMIT 100;
# Out:
#     dateid  catid  venueid  eventid           eventname  \
# 0     1827      6      238     1217          Mamma Mia!
# 1     1827      7      207     2811    Spring Awakening
# 2     1827      9       72     6711   Smashing Pumpkins
# 3     1827      9        6     7747           K.D. Lang
# 4     1828      7      209     2920             Macbeth
# ..     ...    ...      ...      ...                 ...
# 95    1840      7      214     1970       The Caretaker
# 96    1840      7      209     2907  Look Back in Anger
# 97    1840      7      217     3339            Thurgood
# 98    1840      9       28     4476         Temptations
# 99    1840      9       48     5966    Rick Springfield
#
#                    starttime                  venuename        venuecity  \
# 0  2008-01-01 20:00:00+00:00      Winter Garden Theatre    New York City
# 1  2008-01-01 15:00:00+00:00  Bernard B. Jacobs Theatre    New York City
# 2  2008-01-01 19:00:00+00:00   Cleveland Browns Stadium        Cleveland
# 3  2008-01-01 15:00:00+00:00    New York Giants Stadium  East Rutherford
# 4  2008-01-02 19:30:00+00:00              Booth Theatre    New York City
# ..                       ...                        ...              ...
# 95 2008-01-14 15:00:00+00:00    George Gershwin Theatre    New York City
# 96 2008-01-14 19:00:00+00:00              Booth Theatre    New York City
# 97 2008-01-14 19:30:00+00:00             Hilton Theatre    New York City
# 98 2008-01-14 19:00:00+00:00    American Airlines Arena            Miami
# 99 2008-01-14 19:00:00+00:00                 HSBC Arena          Buffalo
#
#    venuestate  venueseats  catgroup   catname  \
# 0          NY         0.0     Shows  Musicals
# 1          NY         0.0     Shows     Plays
# 2          OH     73200.0  Concerts       Pop
# 3          NJ     80242.0  Concerts       Pop
# 4          NY         0.0     Shows     Plays
# ..        ...         ...       ...       ...
# 95         NY         0.0     Shows     Plays
# 96         NY         0.0     Shows     Plays
# 97         NY         0.0     Shows     Plays
# 98         FL         0.0  Concerts       Pop
# 99         NY         0.0  Concerts       Pop
#
#                             catdesc                   caldate  day  week  \
# 0                   Musical theatre 2008-01-01 00:00:00+00:00  WE      1
# 1           All non-musical theatre 2008-01-01 00:00:00+00:00  WE      1
# 2   All rock and pop music concerts 2008-01-01 00:00:00+00:00  WE      1
# 3   All rock and pop music concerts 2008-01-01 00:00:00+00:00  WE      1
# 4           All non-musical theatre 2008-01-02 00:00:00+00:00  TH      1
# ..                              ...                       ...  ...   ...
# 95          All non-musical theatre 2008-01-14 00:00:00+00:00  TU      3
# 96          All non-musical theatre 2008-01-14 00:00:00+00:00  TU      3
# 97          All non-musical theatre 2008-01-14 00:00:00+00:00  TU      3
# 98  All rock and pop music concerts 2008-01-14 00:00:00+00:00  TU      3
# 99  All rock and pop music concerts 2008-01-14 00:00:00+00:00  TU      3
#
#     month  qtr  year  holiday
# 0   JAN      1  2008     True
# 1   JAN      1  2008     True
# 2   JAN      1  2008     True
# 3   JAN      1  2008     True
# 4   JAN      1  2008    False
# ..    ...  ...   ...      ...
# 95  JAN      1  2008    False
# 96  JAN      1  2008    False
# 97  JAN      1  2008    False
# 98  JAN      1  2008    False
# 99  JAN      1  2008    False
#
# [100 rows x 20 columns]

# %% [markdown]
# ## Analyzing Duplicates
# -- There's a `starttime` column coming from the `event` table and there's also a `caldate` column, coming from the `date` table. Let's see what's up with this.

# %%
SELECT
	CASE WHEN DATE(caldate) = DATE(starttime) THEN True ELSE False END AS same_date,
	COUNT(*)
FROM event
INNER JOIN date USING(dateid)
GROUP BY 1
# Out:
#    same_date  count
# 0      False    703
# 1       True   8095

# %% [markdown]
# - So, there are 703 recirds, where the 'caldate' column does not match up with the 'starttime' column.
# - Now, let's find out the maximum difference (in hours) between the 'caldate' time and 'startime' time.

# %%
-- Using the DATEDIFF function here to calculate the diff in hours
SELECT MAX(DATEDIFF('hour', caldate, starttime))
FROM event
INNER JOIN date USING(dateid)
# Out:
#    max
# 0   20

# %% [markdown]
# - The Maximum difference is just 20 hours.
# - However, for our analysis, we can just leave this as is because we're more interested in the 'users' data.

# %% [markdown]
# ## Adding in More Variables
# - Let's see how much events are happening in different cities.

# %%
SELECT 
	venuecity,
    COUNT(*) AS num_events
FROM event
INNER JOIN venue USING(venueid)
GROUP BY 1
ORDER BY 2 DESC
# Out:
#         venuecity  num_events
# 0   New York City        2647
# 1     Los Angeles         312
# 2       Las Vegas         300
# 3         Chicago         209
# 4   San Francisco         194
# ..            ...         ...
# 74       Montreal          27
# 75         Newark          27
# 76         Irving          25
# 77        Sunrise          24
# 78        Calgary          18
#
# [79 rows x 2 columns]

# %% [markdown]
# - New York City hosted the most number of events.
# - Calgary, on the other hand, hosted the least amount of events.

# %% [markdown]
# ## Data Viz
# - Let's use Python's plotly library for visulaizing this data.

# %%
# Import plotly
import plotly.express as px

# Bar plot
px.bar(events_per_city, x = 'venuecity', y = 'num_events')
# Out:
# <div>                            <div id="14f91898-d722-445f-bda5-6267455b6701" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14f91898-d722-445f-bda5-6267455b6701")) {                    Plotly.newPlot(                        "14f91898-d722-445f-bda5-6267455b6701",                        [{"alignmentgroup":"True","hovertemplate":"venuecity=%{x}<br>num_events=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["New York City","Los Angeles","Las Vegas","Chicago","San Francisco","Washington","Houston","Detroit","Boston","Baltimore","Seattle","Denver","Minneapolis","St. Louis","Toronto","Cleveland","Philadelphia","Pittsburgh","Atlanta","San Jose","Glendale","Milwaukee","Kansas City","Cincinnati","Oakland","Phoenix","Columbus","San Diego","New Orleans","East Rutherford","Salt Lake City","Dallas","Nashville","Anaheim","Pasadena","Saratoga","Charlotte","Tampa","Indianapolis","Galveston","Edmonton","Santa Clara","Bridgeview","Mountain View","Charleston","Commerce City","Memphis","Auburn Hills","St. Paul","Sacramento","Landover","Miami Gardens","Portland","Frisco","Orlando","Uniondale","Oklahoma City","Saratoga Springs","Carson","Vancouver","Redwood City","Arlington","San Antonio","Dayton","Ottawa","Miami","Hershey","Raleigh","Green Bay","Buffalo","Jacksonville","St. Petersburg","Foxborough","Orchard Park","Montreal","Newark","Irving","Sunrise","Calgary"],"xaxis":"x","y":[2647,312,300,209,194,164,155,152,144,142,136,136,131,127,120,114,114,109,108,103,94,92,91,88,87,85,84,83,79,76,73,73,70,69,69,67,66,66,62,58,54,50,49,48,47,47,45,43,42,42,42,42,41,41,41,40,40,40,40,40,39,39,39,39,39,39,38,38,37,37,34,34,32,31,27,27,25,24,18],"yaxis":"y"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[ ...

# %% [markdown]
# ## Explore listings and sales

# %% [markdown]
# - There are two tables that we haven't touched so far (sales & listings).
# - These are important if we want to calucate revenue (money made from sales)
# - Let's explore them here

# %%
-- show 100 listing records
SELECT * FROM listing LIMIT 100;
# Out:
#     listid  sellerid  eventid  dateid  numtickets  priceperticket  totalprice  \
# 0     2092     42560     8609    1827          22           194.0      4268.0
# 1     9242     31448     7441    1827          14            88.0      1232.0
# 2     9730      8250     2772    1827          20           146.0      2920.0
# 3    11176     39919     5362    1827          12           107.0      1284.0
# 4    11615     15795     5157    1827           4           221.0       884.0
# ..     ...       ...      ...     ...         ...             ...         ...
# 95   10309     13587     3797    1828           4            96.0       384.0
# 96   10900     33297     1281    1828          12           217.0      2604.0
# 97   10970     31450     7546    1828           1           105.0       105.0
# 98   21681     47532     5346    1828          28            67.0      1876.0
# 99   22412     42508     3139    1828           4           185.0       740.0
#
#                     listtime
# 0  2008-01-01 05:49:06+00:00
# 1  2008-01-01 02:39:54+00:00
# 2  2008-01-01 09:46:40+00:00
# 3  2008-01-01 10:18:43+00:00
# 4  2008-01-01 06:02:18+00:00
# ..                       ...
# 95 2008-01-02 01:51:41+00:00
# 96 2008-01-02 05:12:22+00:00
# 97 2008-01-02 06:59:22+00:00
# 98 2008-01-02 07:59:20+00:00
# 99 2008-01-02 06:09:05+00:00
#
# [100 rows x 8 columns]

# %%
-- show 100 sales records
SELECT * FROM sales LIMIT 100;
# Out:
#     salesid  listid  sellerid  buyerid  eventid  dateid  qtysold  pricepaid  \
# 0     65082   73790     20429      451     1150    1827        4      472.0
# 1     84644   96603      6051     1312     6641    1828        2      810.0
# 2    160330  212426     37430      447     6884    1828        4     8672.0
# 3     16536   17885     33096     1739     7443    1829        2      342.0
# 4     64837   73489     21131     2375     4488    1829        2      156.0
# ..      ...     ...       ...      ...      ...     ...      ...        ...
# 95   111878  128148     10913     1462     2524    1835        1      335.0
# 96   112994  129445      6289      261     2472    1835        2      472.0
# 97   115182  131852     18717     5993     3884    1835        1      351.0
# 98   116332  133228     36608     6824     2676    1835        1      204.0
# 99   142399  164770     40822     2245     8069    1835        2       64.0
#
#     commission                  saletime
# 0        70.80 2008-01-01 06:06:57+00:00
# 1       121.50 2008-01-02 09:31:15+00:00
# 2      1300.80 2008-01-02 03:20:32+00:00
# 3        51.30 2008-01-03 06:36:27+00:00
# 4        23.40 2008-01-03 05:58:02+00:00
# ..         ...                       ...
# 95       50.25 2008-01-09 10:20:55+00:00
# 96       70.80 2008-01-09 01:51:41+00:00
# 97       52.65 2008-01-09 06:27:11+00:00
# 98       30.60 2008-01-09 05:10:56+00:00
# 99        9.60 2008-01-09 08:42:42+00:00
#
# [100 rows x 10 columns]

# %% [markdown]
# - Let's see if multiple sales can happen for the same listing.
# - In other words, are there multiple sales associated with the same listid?
# - Here, I'll be using SQL's 'HAVING' clause.

# %%
    SELECT 
        listid,
        COUNT(*) AS number_of_sales
    FROM listing
	INNER JOIN sales USING(listid)
    GROUP BY 1
    HAVING COUNT(*) > 1;
# Out:
#        listid  number_of_sales
# 0       18088                2
# 1       18250                3
# 2       45435                3
# 3       56766                3
# 4       57663                2
# ...       ...              ...
# 53050  172518                2
# 53051   60494                2
# 53052   45075                2
# 53053  101779                2
# 53054   92363                2
#
# [53055 rows x 2 columns]

# %% [markdown]
# - Using the abouve query as a Common Table Expression, let's count how many sales happened once as well as 'more than once'.

# %%
WITH listings_with_sales AS (
    SELECT 
        listid,
        COUNT(*) AS number_of_sales
    FROM listing
	INNER JOIN sales USING(listid)
    GROUP BY 1
)
SELECT
	number_of_sales,
    COUNT(*)
FROM listings_with_sales
GROUP BY 1
ORDER BY 1
# Out:
#    number_of_sales  count
# 0                1  48029
# 1                2  36570
# 2                3  14665
# 3                4   1808
# 4                5     12

# %% [markdown]
# - It turns out the bulk of listings have only one sale associated with them.
# - However, There are 12 listings that had 5 sales.

# %% [markdown]
# ## User Data
# - It's time to put some names to numbers.
# - Let's see how many tickets (qty) did each user sell.

# %%
SELECT
	sellerid,
    username,
    (firstname ||' '|| lastname) as name, -- this is a shortcut way to use the CONCAT method
	city,
    sum(qtysold)
FROM sales
INNER JOIN date USING(dateid)
INNER JOIN users ON sales.sellerid = users.userid
WHERE year = 2008
GROUP BY 1, 2, 3, 4
ORDER BY 5 desc
LIMIT 5
# Out:
#    sellerid  username              name         city  sum
# 0     48950  TUT90BHI        Nayda Hood       Frisco   46
# 1     20029  RPM45HGY      Drew Mcguire    Lancaster   41
# 2     19123  DZW00VOQ     Scott Simmons       Carson   41
# 3     36791  DCE77DOA  Emerson Delacruz  Springfield   40
# 4     41579  QXQ28WLA   Harrison Durham     Anaconda   39

# %% [markdown]
# - Similarly, we can find the most active buyer on the site in 2008.
# - These are the buyers, who bought the tickets from the sellers.

# %%
select
	buyerid,
    username,
    (firstname ||' '|| lastname) as name,
	city,
    sum(qtysold)
FROM sales
INNER JOIN date USING(dateid)
INNER JOIN users ON sales.buyerid = users.userid
WHERE year = 2008
GROUP BY 1, 2, 3, 4
ORDER BY 5 desc
LIMIT 5
# Out:
#    buyerid  username           name          city  sum
# 0     8933  CNF70VPH  Jerry Nichols    Middlebury   67
# 1     1298  EDB46JXK  Kameko Bowman   Newburyport   64
# 2     3797  KTV94TWB  Armando Lopez        Pomona   64
# 3     5002  CBC51API  Kellie Savage  Falls Church   63
# 4     4064  IQS59DPH   Kadeem Blair       Anaheim   60

# %% [markdown]
# ## Analyzing the Prices
# - Let's see if there's a big difference in average sales price for different categories of events. We're looking at actual sales here, not listings!
# - Here, we're using some summary statistics to get agood grasp pn the data.

# %%
SELECT
	catgroup,
    AVG(pricepaid/qtysold) AS avg_ticket_price,
    MEDIAN(pricepaid/qtysold) AS median_ticket_price
FROM sales
INNER JOIN event USING(eventid)
INNER JOIN category USING(catid)
GROUP BY 1
# Out:
#    catgroup  avg_ticket_price  median_ticket_price
# 0  Concerts        333.755006                229.0
# 1     Shows        336.982704                232.0

# %% [markdown]
# Some observations:
# - Median is lower than the average. This means that there are outliers (high sale prices).
# - The graph is rightly Skewed.

# %% [markdown]
# ## Time Discrepencies
# Are there listings where the sale happened before the listing?

# %%
SELECT COUNT(*)
FROM listing
INNER JOIN sales USING (listid)
WHERE listtime > saletime
# Out:
#    count
# 0   2965

# %% [markdown]
# - Turns out there are instances where this happened.
# - This must be bad data! Let's keep these out when figuring out the shortest and longest time to get a listing sold.
# - I'll be usind the DATEDIFF function here.

# %%
WITH tts AS (
    SELECT DATEDIFF('seconds', listtime, saletime) AS time_to_sell
    FROM sales
    INNER JOIN listing USING(listid)
    WHERE listtime < saletime
)
SELECT 
	MIN(time_to_Sell) AS shortest_time_to_sell_in_seconds,
    MAX(time_to_Sell)/3600/24 AS longest_time_to_sell_in_days
FROM tts
# Out:
#    shortest_time_to_sell_in_seconds  longest_time_to_sell_in_days
# 0                                17                            60

# %% [markdown]
# ## Finding users that should advertise
#
# Suppose we, as owners of the ticketing website, want to target certain users with the suggestion to advertise their listings, so they have a higher chance of actually getting sales. Let's build up a list of users that had the most outstanding listings in terms of price per ticket.

# %% [markdown]
# - First, let's see which users did not sell any tickets.
# - I'll be using the LEFT join
# - Also, using the COALESCE funtion I'll replace NUll values with 0.

# %%
SELECT  listid,
 	    COALESCE(qtysold, 0)
    FROM listing
		LEFT JOIN sales USING(listid)
WHERE qtysold IS NULL
# Out:
#        listid  coalesce
# 0        8319         0
# 1       60816         0
# 2      122714         0
# 3      160788         0
# 4      220953         0
# ...       ...       ...
# 91408   97982         0
# 91409   37567         0
# 91410  114963         0
# 91411  231458         0
# 91412    1486         0
#
# [91413 rows x 2 columns]

# %% [markdown]
# - Now, let's see which users havenot sold tickets yet.
# - We will calculate their 'unrelaized earnings', which is a fancy way of saying potential revenue.
# - In our advertizing campaign, we can target these users to help them sell.

# %%
WITH listings_with_sales AS (
    SELECT 
        listid,
 	    listing.sellerid,
        numtickets AS tickets_listed,
        priceperticket,
		SUM(COALESCE(qtysold, 0)) AS tickets_sold
    FROM listing
	LEFT JOIN sales USING(listid)
    GROUP BY 1, 2, 3, 4
)
SELECT 
	sellerid,
    (firstname ||' '|| lastname) as name,
	SUM((tickets_listed - tickets_sold) * priceperticket) AS unrealized_sales
FROM listings_with_sales lws
INNER JOIN users ON lws.sellerid = users.userid
GROUP BY 1, 2
ORDER BY 3 DESC
LIMIT 100
# Out:
#     sellerid              name  unrealized_sales
# 0      25428      Jaime Wagner           58395.0
# 1      24896       Macey Ortiz           53086.0
# 2      49322    Dustin Vincent           50914.0
# 3      36926     Audrey Barber           50345.0
# 4      45819     Kelly Barrett           49826.0
# ..       ...               ...               ...
# 95     35926    Ulysses Kinney           38895.0
# 96     45372  Lysandra Sanchez           38862.0
# 97     48188    Caesar Parrish           38847.0
# 98     25373       Jakeem Byrd           38847.0
# 99      1759     Lane Franklin           38740.0
#
# [100 rows x 3 columns]

# %% [markdown]
# - Looks like Jaime Wagner had 58k of unrealized sales!
# - Let's limit this list to people who have more than 40K in unrealized sales.

# %%
WITH listings_with_sales AS (
    SELECT 
        listid,
 	    listing.sellerid,
        numtickets AS tickets_listed,
        priceperticket,
		SUM(COALESCE(qtysold, 0)) AS tickets_sold
    FROM listing
	LEFT JOIN sales USING(listid)
    GROUP BY 1, 2, 3, 4
)
SELECT 
	sellerid,
    (firstname ||' '|| lastname) as name,
	SUM((tickets_listed - tickets_sold) * priceperticket) AS unrealized_sales
FROM listings_with_sales lws
INNER JOIN users ON lws.sellerid = users.userid
GROUP BY 1, 2
HAVING unrealized_sales > 40000
ORDER BY 3 DESC
LIMIT 100
# Out:
#     sellerid             name  unrealized_sales
# 0      25428     Jaime Wagner           58395.0
# 1      24896      Macey Ortiz           53086.0
# 2      49322   Dustin Vincent           50914.0
# 3      36926    Audrey Barber           50345.0
# 4      45819    Kelly Barrett           49826.0
# ..       ...              ...               ...
# 68     20845    Lance Camacho           40152.0
# 69     12380        Amy Cooke           40129.0
# 70     47247     Hayley Lloyd           40122.0
# 71     35355  Kathleen Bonner           40122.0
# 72     39977       Ocean Rios           40057.0
#
# [73 rows x 3 columns]

# %% [markdown]
# # Conclusion
# - Here is the list of the people that we can target for advertizing purposes.
# - Let's convert this list to a bar graph.

# %%
# Bar plot
px.bar(df_users, x = 'name', y = 'unrealized_sales')
# Out:
# <div>                            <div id="9113a7e3-7e07-4821-885b-ea62bfdf1ba6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9113a7e3-7e07-4821-885b-ea62bfdf1ba6")) {                    Plotly.newPlot(                        "9113a7e3-7e07-4821-885b-ea62bfdf1ba6",                        [{"alignmentgroup":"True","hovertemplate":"name=%{x}<br>unrealized_sales=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Jaime Wagner","Macey Ortiz","Dustin Vincent","Audrey Barber","Kelly Barrett","Violet Prince","Kitra Cruz","Jared Haney","Suki Mullen","Herman Richard","Amela Holman","Brandon Ratliff","Cameron Conner","Arsenio Small","Brennan Leach","Carl Small","Charles Dickson","Leila Ochoa","Amos Bennett","Buffy Christian","Bianca Puckett","Dylan Hamilton","Quynn Hernandez","Raymond Mendez","Judith Garcia","Calvin Wallace","Dara Luna","Cairo Ramirez","Angela Cummings","Trevor Benton","Dominic Davenport","Hamish Beasley","Leigh Dillard","Martin Richmond","Jayme Hensley","Charde Larson","Logan David","Sydnee Brady","Casey Key","Roth Riley","Yoshio Goodwin","Idona Gutierrez","Amela Branch","Libby Wallace","Hermione Jacobs","Alden Blankenship","Heidi Ayala","Anne Bray","Portia Palmer","Vladimir Todd","Shay Pickett","Jescie Parker","Virginia Malone","Sloane Mays","Wang Knowles","Ivory Maynard","Eagan Washington","Baker Boyle","Blossom Stokes","Nayda Burch","Ori Ortiz","Nissim Peck","Erica Aguilar","Jason Byers","Tyler Foster","Aidan Howe","Jessamine Garrett","Iola Williams","Lance Camacho","Amy Cooke","Hayley Lloyd","Kathleen Bonner","Ocean Rios"],"xaxis":"x","y":[58395.0,53086.0,50914.0,50345.0,49826.0,48605.0,48483.0,48251.0,47906.0,47290.0,47202.0,46705.0,46595.0,46594.0,46136.0,46027.0,45888.0,45748.0,45472.0,45147.0,44754.0,44541.0,44501.0,44292.0,44083.0,43966.0,43855.0,43826.0,43707.0,43635.0,43605.0,43370.0,42983.0,42928.0,42889.0,42863.0,42853.0,42844.0,42648.0,42514.0,42511.0,42308.0,42254.0,42191.0,42174.0,42011.0,41998.0,41927.0,41783.0,41745.0,41736.0,41584.0,41552.0,41448.0,41359.0,41328.0,41299.0,41246.0,41166.0,41050.0,40763.0,40761.0,40667.0,40577.0,40324.0,40313.0,40265.0,40212.0,40152.0,40129.0,40122.0,40122.0,40057.0],"yaxis":"y"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444 ...

# %% [markdown]
# ## Extra Bit of Detail
# - Let's visualize sales over time and separate them based on category.
# - This can help us to determine the seasonality of the sales.
# - Using the DATE_TRUNC function to extract the 'week' from sales date.

# %%
-- Show total pricepaid on a weekly basis
SELECT
	catgroup,
    DATE_TRUNC('week', saletime) AS sales_week,
    SUM(pricepaid) AS total_sales
FROM sales
INNER JOIN event USING(eventid)
INNER JOIN category USING(catid)
GROUP BY 1, 2
ORDER BY 2;
# Out:
#      catgroup                sales_week  total_sales
# 0    Concerts 2007-12-31 00:00:00+00:00     146716.0
# 1       Shows 2007-12-31 00:00:00+00:00      98275.0
# 2    Concerts 2008-01-07 00:00:00+00:00     420710.0
# 3       Shows 2008-01-07 00:00:00+00:00     313664.0
# 4       Shows 2008-01-14 00:00:00+00:00     532037.0
# ..        ...                       ...          ...
# 101     Shows 2008-12-15 00:00:00+00:00     419135.0
# 102     Shows 2008-12-22 00:00:00+00:00     245468.0
# 103  Concerts 2008-12-22 00:00:00+00:00     289723.0
# 104     Shows 2008-12-29 00:00:00+00:00      37838.0
# 105  Concerts 2008-12-29 00:00:00+00:00      44918.0
#
# [106 rows x 3 columns]

# %%
#Plotting a line graph
import plotly.express as px
px.line(sales_over_week, x = 'sales_week', y = 'total_sales', color = 'catgroup')
# Out:
# <div>                            <div id="424334da-f0a9-4314-9d7c-06219d5d18c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("424334da-f0a9-4314-9d7c-06219d5d18c2")) {                    Plotly.newPlot(                        "424334da-f0a9-4314-9d7c-06219d5d18c2",                        [{"hovertemplate":"catgroup=Concerts<br>sales_week=%{x}<br>total_sales=%{y}<extra></extra>","legendgroup":"Concerts","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"Concerts","orientation":"v","showlegend":true,"type":"scatter","x":["2007-12-31T00:00:00+00:00","2008-01-07T00:00:00+00:00","2008-01-14T00:00:00+00:00","2008-01-21T00:00:00+00:00","2008-01-28T00:00:00+00:00","2008-02-04T00:00:00+00:00","2008-02-11T00:00:00+00:00","2008-02-18T00:00:00+00:00","2008-02-25T00:00:00+00:00","2008-03-03T00:00:00+00:00","2008-03-10T00:00:00+00:00","2008-03-17T00:00:00+00:00","2008-03-24T00:00:00+00:00","2008-03-31T00:00:00+00:00","2008-04-07T00:00:00+00:00","2008-04-14T00:00:00+00:00","2008-04-21T00:00:00+00:00","2008-04-28T00:00:00+00:00","2008-05-05T00:00:00+00:00","2008-05-12T00:00:00+00:00","2008-05-19T00:00:00+00:00","2008-05-26T00:00:00+00:00","2008-06-02T00:00:00+00:00","2008-06-09T00:00:00+00:00","2008-06-16T00:00:00+00:00","2008-06-23T00:00:00+00:00","2008-06-30T00:00:00+00:00","2008-07-07T00:00:00+00:00","2008-07-14T00:00:00+00:00","2008-07-21T00:00:00+00:00","2008-07-28T00:00:00+00:00","2008-08-04T00:00:00+00:00","2008-08-11T00:00:00+00:00","2008-08-18T00:00:00+00:00","2008-08-25T00:00:00+00:00","2008-09-01T00:00:00+00:00","2008-09-08T00:00:00+00:00","2008-09-15T00:00:00+00:00","2008-09-22T00:00:00+00:00","2008-09-29T00:00:00+00:00","2008-10-06T00:00:00+00:00","2008-10-13T00:00:00+00:00","2008-10-20T00:00:00+00:00","2008-10-27T00:00:00+00:00","2008-11-03T00:00:00+00:00","2008-11-10T00:00:00+00:00","2008-11-17T00:00:00+00:00","2008-11-24T00:00:00+00:00","2008-12-01T00:00:00+00:00","2008-12-08T00:00:00+00:00","2008-12-15T00:00:00+00:00","2008-12-22T00:00:00+00:00","2008-12-29T00:00:00+00:00"],"xaxis":"x","y":[146716.0,420710.0,674721.0,895593.0,1059108.0,1095537.0,1236972.0,1264423.0,1044152.0,1266632.0,1282633.0,1411052.0,1304484.0,1446572.0,1349932.0,1360394.0,1377370.0,1364305.0,1388447.0,1469010.0,1383105.0,1268827.0,1322614.0,1407547.0,1386309.0,1333761.0,1443532.0,1334936.0,1415219.0,1466763.0,1477701.0,1320088.0,1370918.0,1348666.0,1286451.0,1411432.0,1429679.0,1345163.0,1301588.0,1382666.0,1281357.0,1266955.0,1263467.0,1291453.0,1330575.0,1210856.0,1036144.0,990987.0,923426.0,725297.0,483357.0,289723.0,44918.0],"yaxis":"y"},{"hovertemplate":"catgroup=Shows<br>sales_week=%{x}<br>total_sales=%{y}<extra></extra>","legendgroup":"Shows","line":{"color":"#EF553B","dash":"solid"},"mode":"lines","name":"Shows","orientation":"v","showlegend":true,"type":"scatter","x":["2007-12-31T00:00:00+00:00","2008-01-07T00:00:00+00:00","2008-01-14T00:00:00+00:00","2008-01-21T00:00:00+00:00","2008-01-28T00:00:00+00:00","2008-02-04T00:00:00+00:00","2008-02-11T00:00:00+00:00","2008-02-18T00:00:00+00:00","2008-02-25T00:00:00+00:00","2008-03-03T00:00:00+00:00","2008-03-10T00:00:00+00:00","2008-03-17T00:00:00+00:00","2008-03-24T00:00:00+00:00","2008-03-31T00:00:00+00:00","2008-04-07T00:00:00+00:00","2008-04-14T00:00:00+00:00","2008-04-21T00:00:00+00:00","2008-04-28T00:00:00+00:00","2008-05-05T00:00:00+00:00","2008-05-12T00:00:00+00:00","2008-05-19T00:00:00+00:00","2008-05-26T00:00:00+00:00","2008-06-02T00:00:00+00:00","2008-06-09T00:00:00+00:00","2008-06-16T00:00:00+00:00","2008-06-23T00:00:00+00:00","2008-06-30T00:00:00+00:00","2008-07-07T00:00:00+00:00","2008-07-14T00:00:00+00:00","2008-07-21T00:00:00+00:00","2008-07-28T00:00:00+00:00","2008-08-04T00:00:00+00:00","2008-08-11T00:00:00+00:00","2008-08-18T00:00:00+ ...
